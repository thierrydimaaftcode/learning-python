# %% [markdown]
# <a href="https://colab.research.google.com/github/thierrydimaaftcode/learning-python/blob/main/Learn1-python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Materi pertama pembelajaran tentang python

# %%
a=2
b=3
c=a+b
print(c)
# Out:
# 5
